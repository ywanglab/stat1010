# %% [markdown]
# # My Jupyter Notebook

# %% [markdown]
# **Yi Wang** (boldfaced using ** **)
#
# Educator
# AUM

# %% [markdown]
# The following line is italicized using * *
#
# *I am interest in data science because it is a discipline that I feel love with.*

# %% [markdown]
# ### Perform addtion

# %%
# code block
1+1
# Out:
# 2

# %% [markdown]
# ### Horizontal Rule
#
# Three or more
#
# first rule using ***
#
# ***
#
# using dashes ---
#
# ---
# Using (underscores) ___
#
# ___

# %% [markdown]
# ### Bulet list
# using *
#
# * Bird
# * Frog
# * Cat
# * Dog

# %% [markdown]
# ### Numbered list
# using 1. item (there is a space between 1. and item)
#
# 1. Apple
# 2. Pear
# 3. Peach

# %% [markdown]
# ### Tables
#
# left-aligned     |   centered    |     right-aligned
# :-------- | :---------: |  ---------:
# 1/2/2020 |   Mary    |   Apple
# 1/3      |  Johnason |    Tomato

# %% [markdown]
# ### Hyperlinks
#
# Click [here](https://github.com/ywanglab) to access my github account.

# %% [markdown]
# ### Images
#
# ![ A computer monitor](https://github.com/adam-p/markdown-here/raw/master/src/common/images/icon48.png)

# %% [markdown]
# ### Code/Syntax highlighting
#
# ```python
# s = "Python syntax highlighting"
# print s
# ```

# %% [markdown]
# ### Blocked quotes
# using >
#
# > Blockquotes are very handy in email to emulate reply text.
#
# > This line is part of the same quote.

# %% [markdown]
# ### Strikethrough
# using ~~  before and after a phrase
#
# ~~strikethrough this~~
